# %% [markdown]
# # Notebook zu Blatt 8

# %%
import test_SelectionSort
# !pip install numpy seaborn

# %%
import numpy as np      # um zufällige arrays zu generieren
import time             # zur zeitmessung
import seaborn as sns   # zum plotten
import SelectionSort
import quicksort2
from typing import List
import unittest
import matplotlib.pyplot as plt

# %% [markdown]
# ####  1. Implementieren Sie Selection Sort und Quicksort in Python

# %%
def selectionSort(array):
    pass # hier Eure Implementierung :)

# %%
array = [7,5,8,1]
SelectionSort.selectionsort(array)
print(array) # das sortierte array

# %%
def quickSort(array):
        pass # hier Eure Implementierung :)

# %%
array = [7,5,8,1,2]
quicksort2.quicksort(array,0,len(array)-1)
print(array) # das sortierte array
# Out:
# [1, 2, 5, 7, 8]

# %% [markdown]
# #### 4. Testen Sie die Korrektheit Ihrer Implementierungen anhand von verschiedenen Testfällen

# %%
# Hier kommen die Testfälle!

# %% [markdown]
# #### 5. Messen Sie die Laufzeit der beiden Sortieralgorithmen auf Ihrem Rechner.

# %%
s_times, q_times = [], []
arrar_sizes =  [10, 100, 500, 1000, 1500, 2000, 2500, 3000, 5000, 7500, 10000] # messung für verschiedenen array-längen
for size in arrar_sizes:
    # ziehe ein zufälliges array
    np.random.seed(0)
    array = np.random.randint(low=0, high=1000000, size=size)
    start = time.time()
    SelectionSort.selectionsort(array)
    # hier sortieren mit selection sort - wie geht das?
    end = time.time()
    s_times.append(end-start) # die zeit in sekunden

    # und dann jetzt noch für quicksort :)

for size in arrar_sizes:
    # ziehe ein zufälliges array
    np.random.seed(0)
    array = np.random.randint(low=0, high=1000000, size=size)
    start = time.time()
    quicksort2.quicksort(array,0,len(array)-1)
    # hier sortieren mit selection sort - wie geht das?
    end = time.time()
    q_times.append(end-start) # die zeit in sekunden

# %% [markdown]
# #### 6. Erstellen Sie einen geeignent Plot, der die Laufzeit der beiden Algorithmen in Abhängigkeit von der Eingabelänge darstellt

# %%
# Hier kommet der Plot!
sns.lineplot(x = arrar_sizes, y = s_times, linestyle="dashed", marker="o")
plt.xlabel("Array Groeßen)
plt.ylabel("Laufzeit in Sekunden")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 2
#       1 # Hier kommet der Plot!
# ----> 2 sns.lineplot(x = arrar_sizes, y = s_times, linestyle="dashed", marker="o")
#       3 plt.xlabel("Parameter n")
#       4 plt.ylabel("Laufzeit in Sekunden")
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:489, in _LinePlotter.plot(self, ax, kws)
#     486 if self.err_style == "band":
#     488     func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
# --> 489     func(
#     490         sub_data[orient],
#     491         sub_data[f"{other}min"], sub_data[f"{other}max"],
#     492         color=line_color, **err_kws
#     493     )
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
sns.lineplot(x = arrar_sizes, y = q_times, linestyle="dashed", marker="o")
plt.xlabel("Array Groeßen")
plt.ylabel("Laufzeit in Sekunden")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 sns.lineplot(x = arrar_sizes, y = q_times, linestyle="dashed", marker="o")
#       2 plt.xlabel("Parameter n")
#       3 plt.ylabel("Laufzeit in Sekunden")
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:489, in _LinePlotter.plot(self, ax, kws)
#     486 if self.err_style == "band":
#     488     func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
# --> 489     func(
#     490         sub_data[orient],
#     491         sub_data[f"{other}min"], sub_data[f"{other}max"],
#     492         color=line_color, **err_kws
#     493     )
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# #### 7. Erstellen Sie für die beiden Sortieralgorithmen jeweils einen Plot, in dem gemessene Laufzeit durch die entsprechende asymptotische Laufzeitentwicklung approximiert wird.

# %%
# Hier kommen die Plots!
n_cubic = arrar_sizes*np.array(arrar_sizes)*arrar_sizes
C = s_times[-1] / n_cubic[-1]
print(C)

s_asympt = C*n_cubic
sns.lineplot(x = arrar_sizes, y = s_times, linestyle="dashed", marker="o")
sns.lineplot(x = arrar_sizes, y = s_asympt, linestyle="dashed", marker="o")
# Out:
# -1.3981442588146199e-08
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 7
#       4 print(C)
#       6 s_asympt = C*n_cubic
# ----> 7 sns.lineplot(x = arrar_sizes, y = s_times, linestyle="dashed", marker="o")
#       8 sns.lineplot(x = arrar_sizes, y = s_asympt, linestyle="dashed", marker="o")
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:489, in _LinePlotter.plot(self, ax, kws)
#     486 if self.err_style == "band":
#     488     func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
# --> 489     func(
#     490         sub_data[orient],
#     491         sub_data[f"{other}min"], sub_data[f"{other}max"],
#     492         color=line_color, **err_kws
#     493     )
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
n_cubic = arrar_sizes*np.array(arrar_sizes)*arrar_sizes
C = q_times[-1] / n_cubic[-1]
print(C)

q_asympt = C*n_cubic
sns.lineplot(x = arrar_sizes, y = q_times, linestyle="dashed", marker="o")
sns.lineplot(x = arrar_sizes, y = q_asympt, linestyle="dashed", marker="o")
# Out:
# -6.890696471809625e-11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 6
#       3 print(C)
#       5 q_asympt = C*n_cubic
# ----> 6 sns.lineplot(x = arrar_sizes, y = q_asympt, linestyle="dashed", marker="o")
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:489, in _LinePlotter.plot(self, ax, kws)
#     486 if self.err_style == "band":
#     488     func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
# --> 489     func(
#     490         sub_data[orient],
#     491         sub_data[f"{other}min"], sub_data[f"{other}max"],
#     492         color=line_color, **err_kws
#     493     )
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#### 8. Vergleichen Sie die Laufzeit ihrer effizienten Implementierungen mit der Laufzeit der nativen sort() Funktion für Listen in Python

# %%
sortier_times = []
arrar_sizes =  [10, 100, 500, 1000, 1500, 2000, 2500, 3000, 5000, 7500, 10000]
for size in arrar_sizes:
    # ziehe ein zufälliges array
    np.random.seed(0)
    array = np.random.randint(low=0, high=1000000, size=size)
    start = time.time()
    array.sort()
    end = time.time()
    sortier_times.append(end-start)

# %%
sns.lineplot(x = arrar_sizes, y = sortier_times, linestyle="dashed", marker="o")
plt.xlabel("Array Groeßen")
plt.ylabel("Laufzeit in Sekunden")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 sns.lineplot(x = arrar_sizes, y = sortier_times, linestyle="dashed", marker="o")
#       2 plt.xlabel("Array Groeßen")
#       3 plt.ylabel("Laufzeit in Sekunden")
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\seaborn\relational.py:489, in _LinePlotter.plot(self, ax, kws)
#     486 if self.err_style == "band":
#     488     func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
# --> 489     func(
#     490         sub_data[orient],
#     491         sub_data[f"{other}min"], sub_data[f"{other}max"],
#     492         color=line_color, **err_kws
#     493     )
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\matplotlib\axes\_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File ~\PycharmProjects\Übungsblatt8\venv\lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Hier kommt eure Laufzeitanalyse!
