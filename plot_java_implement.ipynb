# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Laufzeitgraphik der Java-Implementation
xs = [10, 100, 500, 1000, 1500, 2000, 2500, 3000, 5000, 7500, 10000]
ys = [4200, 104200, 1641700, 1454900, 2604500, 5259900, 732400, 1027200, 2914600, 6331500, 10259100]
plt.title('Laufzeitmessungen')
plt.ylabel('Laufzeit in ms')
plt.xlabel('Größe des Arrays')
plt.plot(xs,ys, 'bo--')
